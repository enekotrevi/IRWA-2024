# %% [markdown]
# ## IRWA Final Project

# %% [markdown]
# #### Load Python packages
# Let's first import all the packages that we will need during the project.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/bertamitjavilapita/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/bertamitjavilapita/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#!pip install gensim

# %%
import pandas as pd
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy
import collections
from numpy import linalg as la
import time
import re
from collections import Counter
import statistics
import json
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import ast
import pickle
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load data into memory

# %% [markdown]
# **Data:** dataset of processed tweets that contains the following information for each tweet: Tweet, Date, Hashtags, Hashtags_count, Likes, Retweets, Url, and docId. Additionally, there is an evaluation dataset that will be useful for the evaluation part of the project, which includes the following information: docId, query_id, and label.

# %%
# import the processed tweet dataset
doc_path_1 = 'Data/'
doc_path_2 = '/Users/bertamitjavilapita/Desktop/BERTA/UPF/4RT/IRWA/PROJECT/IRWA Project summary and first deliverable/data/'
processed_tweets_df = pd.read_csv(doc_path_1 + 'processed_tweets.csv')

# %%
# read the evaluation file and immediately delete the last row - nan values (empty line), the file is invalid
evaluation_df = pd.read_csv(doc_path_2 + 'evaluation.csv', sep=';').iloc[:-1]

# %% [markdown]
# ### Part 2: Indexing and Evaluation

# %% [markdown]
# #### Indexing

# %% [markdown]
# **1. Build inverted index: After having pre-processed the data, you can then create the inverted index.**

# %%
# convert elements of column tweet to from string to lists in order to apply indexing
processed_tweets_df['Tweet'] = processed_tweets_df['Tweet'].apply(lambda x: ast.literal_eval(x))

# %%
def create_index_tfidf(tweets_df, num_tweets):
    """
    Implement the inverted index and compute tf, df and idf

    Argument:
    tweets_df -- collection of processed tweets in pandas dataset form
    num_tweets -- total number of tweets

    Returns:
    index - the inverted index (implemented through a Python dictionary) containing terms as keys and the corresponding
    list of document these keys appears in (and the positions) as values.
    tf - normalized term frequency for each term in each document
    df - number of documents each term appear in
    idf - inverse document frequency of each term
    """

    # obtain the tweets content
    #lines = tweets_df['Tweet']
    #page_ids = tweets_df['docId']

    index = defaultdict(list)
    tf = defaultdict(list)  # term frequencies of terms in documents (documents in the same order as in the main index)
    df = defaultdict(int)  # document frequencies of terms in the corpus
    title_index = defaultdict(str)
    idf = defaultdict(float)

    # iterate trough tweets
    for row in tweets_df.itertuples():
        # obtain the tweets content
        line = row.Tweet
        page_id = row.docId

        ## ===============================================================
        ## create the index for the **current page** and store it in current_page_index
        ## current_page_index ==> { ‘term1’: [current_doc, [list of positions]], ...,‘term_n’: [current_doc, [list of positions]]}

        ## Example: if the curr_doc has id 1 and his text is
        ##"web retrieval information retrieval":

        ## current_page_index ==> { ‘web’: [1, [0]], ‘retrieval’: [1, [1,4]], ‘information’: [1, [2]]}

        ## the term ‘web’ appears in document 1 in positions 0,
        ## the term ‘retrieval’ appears in document 1 in positions 1 and 4
        ## ===============================================================

        current_page_index = {}

        # line contain a list of terms for each tweet content
        for position, term in enumerate(line):
            try:
                # if the term is already in the dict append the position to the corresponding list
                current_page_index[term][1].append(position)
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                current_page_index[term]=[page_id, array('I',[position])] #'I' indicates unsigned int (int in Python)

        #normalize term frequencies
        # Compute the denominator to normalize term frequencies (formula 2 above)
        # norm is the same for all terms of a document.
        norm = 0
        for term, posting in current_page_index.items():
            # posting will contain the list of positions for current term in current document.
            # posting ==> [current_doc, [list of positions]]
            # you can use it to infer the frequency of current term.
            norm += len(posting[1]) ** 2
        norm = math.sqrt(norm)

        # calculate the tf(dividing the term frequency by the above computed norm) and df weights
        for term, posting in current_page_index.items():
            # append the tf for current term (tf = term frequency in current doc/norm)
            tf[term].append(np.round(len(posting[1])/norm,4)) ## SEE formula (1) above
            #increment the document frequency of current term (number of documents containing the current term)
            df[term] += 1 # increment DF for current term

        #merge the current page index with the main index
        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)

        # Compute IDF following the formula (3) above. HINT: use np.log
        for term in df:
            idf[term] = np.round(np.log(float(num_tweets/df[term])), 4)

    return index, tf, df, idf

# %%
num_tweets = len(processed_tweets_df)
index, tf, df, idf = create_index_tfidf(processed_tweets_df, num_tweets)

# %%
# ater creating the index, tf, df, and idf, serialize them
def serialize_data(index, tf, df, idf, filepath="index_data.pkl"):
    with open(filepath, 'wb') as f:
        pickle.dump((index, tf, df, idf), f)

# %%
# lo load the serialized data for future use
def load_serialized_data(filepath="index_data.pkl"):
    with open(filepath, 'rb') as f:
        index, tf, df, idf = pickle.load(f)
    return index, tf, df, idf

# %%
# first time using index

# Serialize the data to avoid recomputation in the future
serialize_data(index, tf, df, idf, filepath=doc_path_1 + "index_data.pkl")

# %%
# load the serialized data from the file for future use
index, tf, df, idf = load_serialized_data(filepath=doc_path_1 + "index_data.pkl")

# %% [markdown]
# **2. Propose test queries: Define five queries that will be used to evaluate your search engine (e.g., “Indian protest”, “support farmers”)**
#
# When evaluating a search engine, it's crucial to use a variety of search terms that represent different topics and formats. This ensures that the engine is tested across a wide range of real-world scenarios users typically face. To do this effectively, we will choose popular search terms. Here are the five queries we'll be using for this evaluation:
#
# - "Indian government response to farmers"
# - "International support for farmers"
# - "Demands of farmers' protests"
# - "Police action during farmers protest"
# - "Schedules and locations of demonstrations and protests"

# %% [markdown]
# **3. Rank your results: Implement the TF-IDF algorithm and provide ranking based results.**

# %%
# function from part 1 to process tweets
def process_tweet(tweet):

    """
    Preprocess the tweet removing stop words, stemming,
    transforming in lowercase and return the tokens of the text.

    Argument:
    line -- string (tweet) to be preprocessed

    Returns:
    tweet - a list of tokens corresponding to the input text after the preprocessing
    """

    stemmer = PorterStemmer() # define the stemmer
    stop_words = set(stopwords.words("english")) # define the stopwords
    tweet =  tweet.lower() # transform the line to lowercase
    tweet = tweet.replace('\\n', '') # remove newline characters
    tweet = ' '.join(tweet.split()) # remove extra whitespaces
    tweet = re.sub(r'\S*https?:\S*', '', tweet) # delete URLs on the tweet because we won't be able to access to them
    tweet.strip() # remove spaces at first and at the end of a message
    tweet = re.sub(r' ?#\S+', '', tweet) # remove word that is with the hastag - hastag is saved separately
    tweet = re.sub(r'[^a-z0-9#@ ]+', '', tweet) # remove punctuation
    tweet = re.sub(r'[^\w\s]', '', tweet) # delete punctuation
    tweet = tweet.split() # tokenize the text to get a list of terms
    tweet = [word for word in tweet if word not in stop_words] # eliminate the stopwords
    tweet = [stemmer.stem(word) for word in tweet] # perform stemming

    return tweet

# %%
def rank_documents(terms, docs, index, idf, tf):
    """
    Perform the ranking of the results of a search based on the tf-idf weights

    Argument:
    terms -- list of query terms
    docs -- list of documents, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies

    Returns:
    Print the list of ranked documents
    """

    # I'm interested only on the element of the docVector corresponding to the query terms
    # The remaining elements would became 0 when multiplied to the query_vector
    doc_vectors = defaultdict(lambda: [0] * len(terms)) # I call doc_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    query_vector = [0] * len(terms)

    # compute the norm for the query tf
    query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query.
    query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue

        ## Compute tf*idf(normalize TF as done with documents)
        query_vector[termIndex]= query_terms_count[term]/ query_norm * idf[term]

        # Generate doc_vectors for matching docs
        for doc_index, (doc, postings) in enumerate(index[term]):
           # Example of [doc_index, (doc, postings)]
            # 0 (26, array('I', [1, 4, 12, 15, 22, 28, 32, 43, 51, 68, 333, 337]))
            # 1 (33, array('I', [26, 33, 57, 71, 87, 104, 109]))
            # term is in doc 26 in positions 1,4, .....
            # term is in doc 33 in positions 26,33, .....

            #tf[term][0] will contain the tf of the term "term" in the doc 26
            if doc in docs:
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term]  # TODO: check if multiply for idf

    # Calculate the score of each doc
    # compute the cosine similarity between queyVector and each docVector:
    # HINT: you can use the dot product because in case of normalized vectors it corresponds to the cosine similarity
    # see np.dot

    doc_scores=[[np.dot(curDocVec, query_vector), doc] for doc, curDocVec in doc_vectors.items() ]
    doc_scores.sort(reverse=True)

    result_docs = [x[1] for x in doc_scores]
    result_scores = [x[0] for x in doc_scores]

    if len(result_docs) == 0:
        print('No results found, try again')
        query = input()
        docs = search_tf_idf(query, index)
    return result_docs, result_scores

# %%
def search_tf_idf(query, index):
    """
    output is the list of documents that contain any of the query terms.
    So, we will get the list of documents for each query term, and take the union of them.
    """
    query = process_tweet(query)
    docs = set()
    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"
            term_docs=[posting[0] for posting in index[term]]
            docs |= set(term_docs)
        except:
            #term is not in index
            pass
    docs = list(docs)
    ranked_docs = rank_documents(query, docs, index, idf, tf)
    return ranked_docs

# %%
# definition of our queries
queries = ['Indian government response to farmers',
           'International support for farmers',
           "Demands of farmers' protests",
           'Police action during farmers protest',
           'Schedules and locations of demonstrations and protests']

# %%
top = 10
results = {}  # dictionary to store results for each query

# iterate through queries
for i, query in enumerate(queries):
    # execute the search function
    ranked_docs, result_scores = search_tf_idf(query, index)

    # store results in the dictionary
    results[f'ranked_docs_q{i+1}'] = ranked_docs
    results[f'result_scores_q{i+1}'] = result_scores

    print('\n----------------------------------------------------------------------------------------------------------')
    # print the top documents and their scores

    print(f"\nTop {top} results out of {len(ranked_docs)} retrieved documents for the query '{query}':\n")
    for doc_id, score in zip(ranked_docs[:top], result_scores[:top]):
        print(f'docId = {doc_id}\t score = {round(score, 4)}')
# Out:
# ----------------------------------------------------------------------------------------------------------
#
# Top 10 results out of 15989 retrieved documents for the query 'Indian government response to farmers':
#
# docId = doc_3234	 score = 11.8045
# docId = doc_27784	 score = 9.5898
# docId = doc_38114	 score = 9.5064
# docId = doc_38045	 score = 7.8308
# docId = doc_33082	 score = 7.8308
# docId = doc_41021	 score = 7.6648
# docId = doc_13543	 score = 7.5804
# docId = doc_7288	 score = 7.2119
# docId = doc_1353	 score = 7.0977
# docId = doc_39288	 score = 6.7811
#
# ----------------------------------------------------------------------------------------------------------
#
# Top 10 results out of 15767 retrieved documents for the query 'International support for farmers':
#
# docId = doc_859	 score = 10.9298
# docId = doc_21846	 score = 10.9298
# docId = doc_12950	 score = 9.6171
# docId = doc_38762	 score = 8.9963
# docId = doc_27400	 score = 8.9963
# docId = doc_21630	 score = 8.9963
# docId = doc_6713	 score = 8.0471
# docId = doc_28710	 score = 7.4676
# docId = doc_42972	 score = 7.3461
# docId = doc_31474	 score = 7.3461
#
# ----------------------------------------------------------------------------------------------------------
#
# Top 10 results out of 14911 retrieved documents for the query 'Demands of farmers' protests':
#
# docId = doc_15908	 score = 12.1176
# docId = doc_43415	 score = 8.5684
# docId = doc_11006	 score = 7.7504
# docId = doc_17929	 score = 7.5711
# docId = doc_41953	 score = 6.9967
# docId = doc_39659	 score = 6.9967
# docId = doc_1940	 score = 6.9967
# docId = doc_15930	 score = 6.9967
# docId = doc_10445	 score = 6.9967
# docId = doc_18128	 score = 6.937
#
# ----------------------------------------------------------------------------------------------------------
#
# Top 10 results out of 15935 retrieved documents for the query 'Police action during farmers protest':
#
# docId = doc_24374	 score = 11.4668
# docId = doc_13980	 score = 11.4668
# docId = doc_32026	 score = 10.1775
# docId = doc_5491	 score = 7.0523
# docId = doc_34650	 score = 6.8573
# docId = doc_14464	 score = 6.8367
# docId = doc_17561	 score = 6.8188
# docId = doc_33549	 score = 6.6209
# docId = doc_33540	 score = 6.6209
# docId = doc_32143	 score = 6.6209
#
# ----------------------------------------------------------------------------------------------------------
#
# Top 10 results out of 4394 retrieved documents for the query 'Schedules and locations of demonstrations and protests':
#
# docId = doc_43892	 score = 22.7138
# docId = doc_46453	 score = 16.0613
# docId = doc_45516	 score = 16.0613
# docId = doc_44233	 score = 13.193
# docId = doc_45111	 score = 11.9591
# docId = doc_45564	 score = 11.496
# docId = doc_9157	 score = 10.419
# docId = doc_19010	 score = 10.419
# docId = doc_2192	 score = 9.7347
# docId = doc_17302	 score = 9.7347

# %% [markdown]
# #### Evaluation

# %% [markdown]
# There will be 2 main evaluation components:
#
# - A baseline with 2 queries and the ground truth files for each query will be given to you, using a subset of documents from the dataset.
# 1. Query 1: people's rights.
# 2.  Query 2: Indian Government
#
#
# - You will be the expert judges, so you will be setting the ground truth for each document and query in a binary way for the test queries that you defined in step 2 at the indexing stage.

# %% [markdown]
# **Task 1:**
#
# **For the prior evaluation components you must evaluate your algorithm by using different evaluation techniques:**
# - Precision@K (P@K)
# - Recall@K (R@K)
# - Average Precision@K (P@K)
# - F1-Score@K
# - Mean Average Precision (MAP)
# - Mean Reciprocal Rank (MRR)
# - Normalized Discounted Cumulative Gain (NDCG)
#
# **Only for the second component (your queries) comment on each of the evaluation techniques stating how they differ, and which information gives each of them. Analyze your results.**

# %%
# queries definition
defined_queries = ["people's rights",
                   "Indian Government"]

# %%
# head of evaluation dataset
evaluation_df.head(5)
# Out:
#       docId  query_id  label
# 0   doc_156       1.0    0.0
# 1  doc_1039       1.0    0.0
# 2  doc_1047       1.0    1.0
# 3  doc_1685       1.0    0.0
# 4  doc_2100       1.0    1.0

# %%
print_result = evaluation_df["label"].unique()
print("The evaluation of our dataset is composed of {} Relevance Levels: {}".format(len(print_result), sorted(print_result)))
# Out:
# The evaluation of our dataset is composed of 2 Relevance Levels: [0.0, 1.0]

# %%
# create the subset needed for evaluation
evaluation_q1 = evaluation_df[(evaluation_df['query_id'] == 1)]
evaluation_q2 = evaluation_df[(evaluation_df['query_id'] == 2)]

# extract tweets subset from queries by docId
docs_q1 = processed_tweets_df[processed_tweets_df['docId'].isin(evaluation_q1['docId'])]
docs_q2 = processed_tweets_df[processed_tweets_df['docId'].isin(evaluation_q2['docId'])]

# %%
# run the inverted index for each subset - each subset is docs of a query
# then run the search tf-idf performed above
# search preprocess the query

# query 1
indexes_q1, t_q1, d_q1, id_q1  = create_index_tfidf(docs_q1, len(docs_q1))
ranked_docs_q1, result_scores_q1 = search_tf_idf(defined_queries[0], indexes_q1)

# query 2
indexes_q2, t_q2, d_q2, id_q2  = create_index_tfidf(docs_q2, len(docs_q2))
ranked_docs_q2, result_scores_q2 = search_tf_idf(defined_queries[1], indexes_q2)

# %%
# build structure to execute evaluated techniques
# 1. create a dict to map docs with results
# 2. add score do the corresponding docId in evaluating df for the current query
# 3. sort by score
# 4. round with 4 decimals

# to avoid warnings
evaluation_q1 = evaluation_q1.copy()
evaluation_q2 = evaluation_q2.copy()

# query 1.
doc_score_map_q1 = dict(zip(ranked_docs_q1, result_scores_q1))
evaluation_q1.loc[:, 'score'] = evaluation_q1['docId'].map(doc_score_map_q1)
evaluation_q1 = evaluation_q1.sort_values(by='score', ascending=False).reset_index(drop=True)
evaluation_q1['score'] = evaluation_q1['score'].round(4)

# query 2.
doc_score_map_q2 = dict(zip(ranked_docs_q2, result_scores_q2))
evaluation_q2.loc[:, 'score'] = evaluation_q2['docId'].map(doc_score_map_q2)
evaluation_q2.fillna(0, inplace=True)
evaluation_q2 = evaluation_q2.sort_values(by='score', ascending=False).reset_index(drop=True)
evaluation_q2['score'] = evaluation_q2['score'].round(4)

# %% [markdown]
# ##### 1. Precision@K (P@K)

# %%
def precision_at_k(y_true, y_score, k=10):
    '''
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    precision @k : float

    '''
    order = np.argsort(y_score)[::-1]
    y_true = y_true[order[:k]]
    relevant = sum(y_true == 1)
    return float(relevant/k)

# variables -> y_true must be label.
# y_score - predicted relevance

# %% [markdown]
# ##### 2. Recall@K (R@K)

# %%
def recall_at_k(y_true, y_score, k=10):
    '''
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of docs to consider.

    Returns
    -------
    recall @k : float
    '''

    order = np.argsort(y_score)[::-1]
    y_true = y_true[order[:k]]
    relevant = sum(y_true == 1)
    total_relevant = sum(y_true)
    # avoid warning for division by 0
    if total_relevant == 0:
        return 0.0

    # computation of recall
    return float(relevant / total_relevant)

# %% [markdown]
# ##### 3. Average Precision@K (P@K)

# %%
def avg_precision_at_k(y_true, y_score, k=10):
    """
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    average precision @k : float
    """

    order = np.argsort(y_score)[::-1]  # get the list of indexes of the predicted score sorted in descending order.

    prec_at_i = 0
    prec_at_i_list = []
    number_of_relevant = 0
    number_to_iterate = min(k, len(order))

    for i in range(number_to_iterate):
        if y_true[order[i]] == 1:
            number_of_relevant += 1
            prec_at_i = number_of_relevant / (i + 1)
            prec_at_i_list.append(prec_at_i)

    if number_of_relevant == 0:
        return 0
    else:
        return round(np.sum(prec_at_i_list) / number_of_relevant, 4)

# %% [markdown]
# ##### 4. F1-Score@K

# %%
def f1_score_at_k(y_true, y_score, k):
    """
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    f1-score @k : float
    """

    precision_k = precision_at_k(y_true, y_score, k)
    recall_k = recall_at_k(y_true, y_score, k)
    if precision_k + recall_k == 0:
        return 0
    return round((2 * precision_k * recall_k) / (precision_k + recall_k), 4)

# %% [markdown]
# ##### 5. Mean Average Precision (MAP)

# %%
def map_at_k(search_res, k=10):
    '''
    Parameters
    ----------
    search_res: search results dataset containing:
        q_id: query id.
        doc_id: document id.
        predicted_relevance: relevance predicted through LightGBM.
        y_true: actual score of the document for the query (ground truth).

    Returns
    -------
    mean average precision @k : float
    '''
    avp = []
    for q in search_res["query_id"].unique():  #loop over all query id
        curr_data = search_res[search_res["query_id"] == q]  # select data for current query
        avp.append(avg_precision_at_k(np.array(curr_data["label"]), np.array(curr_data["docId"]),
                                      k))  #append average precision for current query
    return round(np.sum(avp) / len(avp), 4), avp  # return mean average precision

# %% [markdown]
# ##### 6. Mean Reciprocal Rank (MRR)

# %%
def rr_at_k(y_true, y_score, k=10):
    """
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    Reciprocal Rank for qurrent query
    """

    # convert into array
    y_true = np.array(y_true)
    y_score = np.array(y_score)

    order = np.argsort(y_score)[::-1] # get the list of indexes of the predicted score sorted in descending order.
    y_true = np.take(y_true, order[:k]) # sort the actual relevance label of the documents based on predicted score(hint: np.take) and take first k.
    if np.sum(y_true) == 0: # if there are not relevant doument return 0
        return 0
    return 1 / (np.argmax(y_true == 1) + 1) # hint: to get the position of the first relevant document use "np.argmax"

# %% [markdown]
# ##### 7. Normalized Discounted Cumulative Gain (NDCG)

# %%
def dcg_at_k(y_true, y_score, k=10):

    # convert into array
    y_true = np.array(y_true)
    y_score = np.array(y_score)

    order = np.argsort(y_score)[::-1]  # get the list of indexes of the predicted score sorted in descending order.
    y_true = np.take(y_true, order[
                             :k])  # sort the actual relevance label of the documents based on predicted score(hint: np.take) and take first k.
    gain = 2 ** y_true - 1  # Compute gain (use formula 7 above)
    discounts = np.log2(np.arange(len(y_true)) + 2)  # Compute denominator
    return np.sum(gain / discounts)  #return dcg@k


def ndcg_at_k(y_true, y_score, k=10):
    dcg_max = dcg_at_k(y_true, y_true, k)
    if not dcg_max:
        return 0
    return np.round(dcg_at_k(y_true, y_score, k) / dcg_max, 4)

# %% [markdown]
# ##### 2.1. Evaluation for predefined queries

# %%
def print_evaluation_metrics(defined_queries, evaluations, k=10):
   
    for i, query in enumerate(defined_queries):
        print("----------------------------------------------------------------------------------------------------------\n")
        print(f"Query: '{query}'\n")
        
        y_true = np.array(evaluations[i]["label"])
        y_score = np.array(evaluations[i]["score"])
        
        precision = precision_at_k(y_true, y_score, k)
        print(f"=> Precision@{k}: {precision}\n")
        
        recall = recall_at_k(y_true, y_score, k)
        print(f"=> Recall@{k}: {recall}\n")
        
        avg_precision = avg_precision_at_k(y_true, y_score, k)
        print(f"=> Average Precision@{k}: {avg_precision}\n")
        
        f1 = f1_score_at_k(y_true, y_score, k)
        print(f"=> F1-Score@{k}: {f1}\n")
        
        map_value = map_at_k(evaluations[i], k)[0]
        print(f"=> MAP with k={k}: {map_value}\n")
        
        mrr = rr_at_k(y_true, y_score, k)
        print(f"=> Mean Reciprocal Rank with k={k}: {mrr}\n")
        
        ndcg = ndcg_at_k(y_true, y_score, k)
        print(f"=> Normalized Discounted Cumulative Gain with k={k}: {ndcg}\n")

# %%
# print results for defined queries
k = 10

# join results in order to the for loop
evaluations = [evaluation_q1, evaluation_q2]
print_evaluation_metrics(defined_queries, evaluations, k)
# Out:
# ----------------------------------------------------------------------------------------------------------
#
# Query: 'people's rights'
#
# => Precision@10: 0.9
#
# => Recall@10: 1.0
#
# => Average Precision@10: 0.9889
#
# => F1-Score@10: 0.9474
#
# => MAP with k=10: 0.8211
#
# => Mean Reciprocal Rank with k=10: 1.0
#
# => Normalized Discounted Cumulative Gain with k=10: 0.9337
#
# ----------------------------------------------------------------------------------------------------------
#
# Query: 'Indian Government'
#
# => Precision@10: 1.0
#
# => Recall@10: 1.0
#
# => Average Precision@10: 1.0
#
# => F1-Score@10: 1.0
#
# => MAP with k=10: 0.361
#
# => Mean Reciprocal Rank with k=10: 1.0
#
# => Normalized Discounted Cumulative Gain with k=10: 1.0

# %% [markdown]
# ##### 2.2. Evaluation for our queries

# %%
# based on the results from step 2, we select the top 30 ranked tweets as "retrieved"
# We build a dataset for each of the 5 queries, including docId, queryId, and label

# we create the evaluation dataset for each query

num = 30
evaluation_datasets = []  # list for evaluation sets for each query 

# loop through each query 
for query_id, query in enumerate(queries):

    #ranked_docs, result_scores = search_tf_idf(query, index)
    ranked_docs = results[f'ranked_docs_q{query_id + 1}']
    result_scores = results[f'result_scores_q{query_id + 1}']
    
    # take the top 30 as "retrieved" (label 1)
    retrieved_docs = ranked_docs[:num]

    # take their correspondant scores
    retrieved_scores = result_scores[:num]

    # list for the actual query
    evaluation_data = []
    
    # add the retrieved docs with label 1 to the evaluation set for the query
    for doc_id, score in zip(retrieved_docs, retrieved_scores):
        evaluation_data.append({"docId": doc_id, "query_id": query_id + 1, "label": 1, "score": round(score, 4)})
    
    # add the results for the query in the evaliation datasets
    evaluation_df = pd.DataFrame(evaluation_data)
    evaluation_datasets.append(evaluation_df)

# %%
# to check for relationships, we'll use the unprocessed tweets since this is the vocabulary we understand
# load the JSON file
# keep only the variables tweetId and Tweet
# merge it with the document dataset

with open(doc_path_2 + 'farmers-protest-tweets.json') as fp:
    tweets = fp.readlines()
tweets = [t.strip().replace(' +', ' ') for t in tweets]

tweet_data = []

# Iterate over each tweet JSON line
for tweet in tweets:
    # Convert JSON string to dictionary
    tweet_dict = json.loads(tweet)
    
    # Extract relevant information
    tweet_id = tweet_dict['id']
    tweet_content = tweet_dict['content']
    
    # Append extracted info as a dictionary
    tweet_data.append({"id": tweet_id, "content": tweet_content})

# Create DataFrame with only 'id' and 'content' columns
tweets_df = pd.DataFrame(tweet_data)

tweet_document_ids_map = pd.read_csv(docs_path + 'tweet_document_ids_map.csv')

tweets_df = tweets_df.merge(tweet_document_ids_map, on='id', how='right')

# %%
# manual check for assess if docs are related to the queries
# Assumptions:
# - `evaluation_datasets` is a list of DataFrames, one for each query, with each DataFrame containing docId, query_id, label, and score.
# - `processed_tweets_df` is a DataFrame that includes a 'docId' column and a 'tweet' column with the tweet content.

for i, evaluation_df in enumerate(evaluation_datasets):
    query = queries[i]  # Retrieve the query associated with this evaluation dataset

    print('--------------------------------------------------------------------------------------------------------------------------------')
    print(f"\n QUERY {i + 1}: {query}\n")
    
    # filter for documents labeled as '1' (retrieved as relevant)
    relevant_docs = evaluation_df[evaluation_df['label'] == 1]
    
    for _, row in relevant_docs.iterrows():
        doc_id = row['docId']
        
        # find the tweet associated with the docId in the processed_tweets_df
        tweet = tweets_df.loc[tweets_df['docId'] == doc_id, 'content'].values
        print(f" - docId: {doc_id} - Tweet: {tweet[0]}\n")
# Out:
# --------------------------------------------------------------------------------------------------------------------------------
#
#  QUERY 1: Indian government response to farmers
#
#  - docId: doc_3234 - Tweet: Nehru is responsible for #ChineseIntrusion
#
# Previous govt is responsible for #PetrolDieselPriceHike
#
# #COVID19 is responsible for economic turmoil
#
# #Khalistan is responsible for #FarmersProtest
#
# Modi isn’t responsible for anything because he is #DaughterofBengal https://t.co/RiXKhTBO34
#
#  - docId: doc_27784 - Tweet: There is no difference between #DeepSidhu #NikitaJacob #Disha_Ravi #GretaThunberg. They all are responsible for #republicdayviolence. #FarmersProtest #FarmBills2020 #ToolkitGang #ToolkitCase #ToolKitExposed #ToolkitAdmission #ToolkitTruthProbe #ToolkitConspiracy #Toolkit
#
#  - docId: doc_38114 - Tweet: Madness!
#
# If the government and Supreme Court has any responsibility please tell the country `If anything happens to her who will be responsible? ' Corona protocols are for certain situations? Karnataka BJP government has no responsibility?
#
# #FarmersProtest #Shame #DishaRavi https://t.co/WuMPogRuds
#
#  - docId: doc_38045 - Tweet: I hold @Google responsible for this. #FarmersProtest https://t.co/NDiy1A9tZw
#
#  - docId: doc_33082 - Tweet: Response from my local MP #FarmersProtest https://t.co/R6v5TrEXOi
#
#  - docId: doc_41021 - Tweet: The Modi government is responsible for the deaths of Navneet and other farmers #ModiGlobalDisaster #FarmersProtest #ReleaseDetainedFarmers https://t.co/GfSsG6Lwk4
#
#  - docId: doc_13543 - Tweet: #DPstopIntimidatingFarmers #FarmersProtest
# Indian govt. is responsible for 200+ deaths of farmers. https://t.co/a1IDdxDYOz
#
#  - docId: doc_7288 - Tweet: Modi you are responsible for the death of farmers
# #ModiIgnoringFarmersDeaths #FarmersProtest https://t.co/vNjX0mkJct
#
#  - docId: doc_1353 - Tweet: The governments response to Farmers revealed them to be a shady group of scallywags.
#
# #ModiDontSellFarmers #FarmersProtest https://t.co/qZe2JlKH90
#
#  - docId: doc_39288 - Tweet: Such a shameful response by this BJP minister #FarmersStandingFirm #FarmersProtest #FarmBills https://t.co/CknDvbnCBz
#
#  - docId: doc_32344 - Tweet: with great power comes no responsibility  #IndiaBeingSilenced #FarmersProtest
#
#  - docId: doc_24570 - Tweet: Very good response to pm Modi
#
# #FarmersProtest https://t.co/8iFZSDjdBG
#
#  - docId: doc_24061 - Tweet: @sandeshnews according to #BJP, Nehru is responsible
#
# #FarmersProtest #PunjabMunicipalElection2021
#
#  - docId: doc_17249 - Tweet: Great response across the nation
#
# #Farmersprotest https://t.co/kOGlhJrXMj
#
#  - docId: doc_34963 - Tweet: Why there is no Response  of government about the farmers?
# Why pm modi is behaving like a dumb?#IndiaBeingSilenced
# #FarmersProtest https://t.co/9z0Y6nVKdU
#
#  - docId: doc_37157 - Tweet: “Between stimulus and response, there is a space.
# In that space is our power to choose our response. ”
# #Farmers
# Roll back Farmers bill
# We aren't going home!
# #FarmersProtest
# #IStandWithFarmers https://t.co/DbmmlI6n6z
#
#  - docId: doc_47642 - Tweet: Tell Congress To Condemn Indian Government Response To #FarmersProtest
# Tell your members of Congress to urgently show solidarity with farmers and condemn Indian government’s undemocratic response to the protest Take 60 seconds and tell your members of Congress to take action now https://t.co/31m0KWyMWY
#
#  - docId: doc_2453 - Tweet: @ik_stip_boeren Power comes with great responsibility.
#
# #allaboutriffle
# #FarmersProtest
# #usewisely
#
#  - docId: doc_19626 - Tweet: This guy takes no responsibility for anything ! Pathetic! 😒 #FarmersProtest https://t.co/ukiEvojesD
#
#  - docId: doc_16612 - Tweet: Inderjit Nikku response to allegations against him @InderjitNikkuu #FarmersProtest https://t.co/y9zNhoTGgZ
#
#  - docId: doc_5169 - Tweet: Spoke with @Kim_SmithTV  on @GlobalEdmonton
# last night about the #FarmersProtest, the Indian government's undemocratic and violent response
#
# Why support for farmers in India continues to grow in Canada https://t.co/bYPAMm55zf
#
#  - docId: doc_21393 - Tweet: @UN published 10 Principles for Responsible investment in Agriculture and Food https://t.co/usCEnznJ4T
#
# Govt. Of India could have performed a responsible job by consulting the farmers before making the agri laws rather than enforcing them.
#
# #FarmersProtest @Bkuektaugrahan
#
#  - docId: doc_13284 - Tweet: @MankamalSingh @Punjab2000music @SikhPA @minkaur5 @SCUKofficial @SikhFedUK @sikhsinscotland @DrJasjitSingh Their response completely ignores the fact that Geeta cuts the speaker off and says,
# “it’s not propaganda.”
#
# In response to @DrSharandeep stating that the govt of Indian is spreading propaganda regarding the farmer’s protests being hijacked.
#
# @BBCNews
#
# #FarmersProtest https://t.co/Tp5A3ajVuE
#
#  - docId: doc_36986 - Tweet: "It is a matter of concern for any human being, because this is just undemocratic." Praneet Soni speaks with @CBCNews about the Indian government's response to the #FarmersProtest and why Canada must stand in solidarity with the protesting farmers. https://t.co/4i2OwYIj5n
#
#  - docId: doc_45649 - Tweet: Amit shah is responsible, question him not the opposition l.
# #FarmersProtest https://t.co/9Gws7inqSW
#
#  - docId: doc_43568 - Tweet: One has a moral responsibility to disobey unjust laws.
#
# #RepealOnlyWayAhead  #FreeRanjitSingh #FarmersProtest https://t.co/e1YfTub1PS
#
#  - docId: doc_10847 - Tweet: Khalisathan is responsible to increase price of diesel and petrol 😀 #farmersProtest #MSPLawForAllCrops
#
#  - docId: doc_10556 - Tweet: RSS-Controlled #DelhiPolice  Bear Responsibility for Defamation of India!
# #FarmersProtest
# @DelhiPolice
#
#  - docId: doc_36378 - Tweet: Govt's stubborn stand responsible for deadlock with farmers: Union  https://t.co/NuQZBUHsbV #FarmersProtest
#
#  - docId: doc_23026 - Tweet: 200+ farmers died. Who is responsible for this?
# #kishanAndolan
# #FarmersMakeIndia
# #FarmersProtest
# @Kisanektamorcha
# @RakeshTikaitBKU
# @INCIndia
# #centralgovernment
#
# --------------------------------------------------------------------------------------------------------------------------------
#
#  QUERY 2: International support for farmers
#
#  - docId: doc_859 - Tweet: #SanFrancisco #USA International support for #FarmersProtest #ModiDontSellFarmers https://t.co/kUZMLLVIoL
#
#  - docId: doc_21846 - Tweet: International support
# #RailRokoForFarmers
# #FarmersProtest https://t.co/uGzzn3YD1x
#
#  - docId: doc_12950 - Tweet: India’s internal matters are no longer internal!
# #FarmersProtest https://t.co/23zd0rBNlz
#
#  - docId: doc_38762 - Tweet: International shame.
#
# #FarmersProtest
# #RepealOnlyWayAhead
# #RepealFarmLaws https://t.co/oFLuKRclj2
#
#  - docId: doc_27400 - Tweet: More international solidarity for the #FarmersProtest
# https://t.co/TO18r3Qn8b
#
#  - docId: doc_21630 - Tweet: But is it not our internal matter???
# #FarmersProtest https://t.co/2W0WIcE9QF
#
#  - docId: doc_6713 - Tweet: @ANI Ok so it's internal matter,,??
# So mean it goes to international level
# #FarmersProtest
#
#  - docId: doc_28710 - Tweet: Bhakts were shouting internal matter, internal matter-now Govt has invited Foreign Diplomats to visit Kashmir.
# Now why is internal matter being discussed/shown? Nice way of Govt to fool it's supporters.
#
# #FarmersProtest #ModiGlobalDisaster #shameonbjp https://t.co/0E2vaocJVZ
#
#  - docId: doc_42972 - Tweet: Why कनाडा is interfering in our internal matter? Or only This "Internal matter" formula applies on criticism? मतलब मीठा मीठा गप्प गप्प, कड़वा कड़वा थू थू! #TruthMatters #JustAsking #FarmersProtest #RepealOnlyWayAhead #किसान_एकता_जिंदाबाद https://t.co/uT9j502vJk
#
#  - docId: doc_31474 - Tweet: Getting that international attention!! #FarmersProtest https://t.co/KWy3U7EU59
#
#  - docId: doc_28358 - Tweet: So much for internal affairs. #FarmersProtest https://t.co/rj7L6jo7iQ
#
#  - docId: doc_27294 - Tweet: Now the matter is not internal... #indiansellebrities should comment again... #FarmersStandingFirm #FarmersProstests #FarmersProtest https://t.co/hFg3xcWlUC
#
#  - docId: doc_25064 - Tweet: Perhaps, it is our internal matter. #InternalMatter #FarmLaws #FarmersProtest #farmerslivesmatter https://t.co/wKJDYhMX77
#
#  - docId: doc_17785 - Tweet: They r waiting for some international celebrities to comment on this. Then they will break the silence by saying it's our internal matter 👇
# #DalitLivesMatter
# #FarmersProtest
# #ReleaseDetainedFarmers https://t.co/UkrPPCG1XB
#
#  - docId: doc_44066 - Tweet: Ohhh yeahhh!  We need more international support!  #FarmersProtest #FarmersStandingFirm #WorldStandsWithFarmers https://t.co/S04cfqn6fz
#
#  - docId: doc_25041 - Tweet: @sanket Regardless to what Narender Government says, internally they know that #FarmersProtest has started receiving international attention and support and this govt. is afraid of everything which is not in its favour or support.
#
#  - docId: doc_42502 - Tweet: @Swamy39 @Aniirudhsharma Wouldn't going to the International Labour Organisation result in #India losing control our what it has referred to as its internal matter? #FarmersProtest
#
#  - docId: doc_6920 - Tweet: Mother of insults at international level 🤣 #yogendrayadav #FarmBills2020 #FarmersProtest https://t.co/XYVUcsczNF
#
#  - docId: doc_6031 - Tweet: @ANI This is an internal matter of India 😉😉😉
# #SachinTendulkar
# #AkshayKumar
# #GodiMedia
# #FarmersProtest
# #DishaRavi
#
#  - docId: doc_48125 - Tweet: Why are interfering in our internal usa business ? 😂  #FarmersProtest
# #MahapanchayatRevolution https://t.co/q9kQ3PRLKi
#
#  - docId: doc_44813 - Tweet: Earth's internal matter vibrated? #earthquake
# #FarmersProtest
#
#  - docId: doc_41492 - Tweet: Wall of Sharm Internationally it is BHEJTEY.            #RepealOnlyWayAhead
# #RepealOnlyWayAhead
# #RepealOnlyWayAhead
# #FarmersProtest https://t.co/bJjbNoJvD8
#
#  - docId: doc_29827 - Tweet: @BDUTT Sure need that. God forbid if anyone speaks. It’s internal matter but among only BJP. No one else is internal. #HumDoHumareDoKiSarkar #IndiaBeingSilenced #FarmersProtest #FarmersStandingFirm
#
#  - docId: doc_28889 - Tweet: How do you explain this @PMOIndia as not being an internal matter?
# #kashmir #IndiaBeingSilenced #FarmersProtest https://t.co/npo65hEh6K
#
#  - docId: doc_27752 - Tweet: We are with you @ClaudiaWebbe. #HumanRightsViolations are not an internal matter of any country.
# #FarmersProtest https://t.co/UYu8eqnFOf
#
#  - docId: doc_27733 - Tweet: #HumanRightsViolations are no one's internal matter! We are with you @ClaudiaWebbe
# #FarmersProtest https://t.co/yyEtSY7OMj
#
#  - docId: doc_1896 - Tweet: Sorry, this is Germany's internal matter #FarmersProtest https://t.co/7GzTgVTncw
#
#  - docId: doc_40138 - Tweet: All international organisations should take self notice and support.
# #FarmersProtest
# #RepealOnlyWayAhead #StandWithFarmers https://t.co/CSOhipjEsD
#
#  - docId: doc_15900 - Tweet: This is arbitrary detention and it is against internationally declared norms for human rights.
# India is violating international treaties.
# #FarmersProtest
# @UNHumanRights @NilsMelzer
# @TLHumanRights @RepMcGovern https://t.co/v808sLnlCs
#
#  - docId: doc_40083 - Tweet: What the fuck is wrong these people !!!! And when international media or celebrities post about Farmers Protest and inhumane treatment of farmers these idiots start whining it’s internal matter !!
#
# #FarmersProtest
# #Stop_Killing_Farmers https://t.co/bRD0qtfcsE
#
# --------------------------------------------------------------------------------------------------------------------------------
#
#  QUERY 3: Demands of farmers' protests
#
#  - docId: doc_15908 - Tweet: demanding
# #kisanektazindabaad
# #FarmersProtest
# #KisanEktaMorcha
#
#  - docId: doc_43415 - Tweet: We demand repeal.
#
# #FarmersProtest
#
#  #RepealOnlyWayAhead https://t.co/dH6fZywMNt
#
#  - docId: doc_11006 - Tweet: Khalistan is not our demand.
# Our demand is MSP!!
# Our demand is repeal the Farm Laws. Repeal the laws and we go home!
#
# #MSPLawForAllCrops
# #FarmersProtest
#
#  - docId: doc_17929 - Tweet: Farmers demand justice #FarmersProtest #ReleaseDetainedFarmers #SupportFarmersProtest https://t.co/2kD6aJLa6d
#
#  - docId: doc_41953 - Tweet: Yess..same demand ...goes on ..
#
# #RepealOnlyWayAhead
# #RepealThreeFarmActs
# #FarmersProtest https://t.co/3saHBe3T2r
#
#  - docId: doc_39659 - Tweet: Demand justice for our bajurgs!
#
# #FarmersProtest https://t.co/tD9M0cb1L5
#
#  - docId: doc_1940 - Tweet: Support the demands but not the way.
#
# #FarmersProtest #farmersbill #delhi
#
# #IndiaTogether
#
# #dbz_diary
#
#  - docId: doc_15930 - Tweet: Why #Farmers demanding MSP? An example below!👇
# #FarmersProtest #ReleaseDetainedFarmers 🥳🔥🚜🌾 https://t.co/qkEpFo3Fno
#
#  - docId: doc_10445 - Tweet: youths demands right.
# #NaukariDoYaDegreeWapasLo
# #MSPLawForAllCrops #MSP_किसान_का_हक #MSP_गारंटी_कानून_बनाओ
# #petrol100 #PetrolPrices #Bollywood #PetrolDieselPriceHike
# #IStandWithFarmers #andolanjeevi #FarmersProtest #FarmersProtests #KisanAandolan #GodiMedia #KisanEktaMorcha https://t.co/i7dPG92IaU
#
#  - docId: doc_18128 - Tweet: I support farmers🚜🌾🌾
#
# You can't suppress our voice
#
# You must meet our demands
#
# Protest will continue until that time does not meet our demands
# #FarmersMakeIndia
# #FarmersProtest
# #KisanEktaZindaabaad
# #ReleaseDetainedFarmers https://t.co/hRQGaaBF1b
#
#  - docId: doc_887 - Tweet: Farmers  demand these laws repealed...                                     #FarmersProtest                           https://t.co/sSOjzA5pEF
#
#  - docId: doc_43810 - Tweet: Proud to be Farmer✊
# We demand Repeal!!
#
# #FarmersProtest
# #RepealOnlyWayAhead https://t.co/ALH0M4mc75
#
#  - docId: doc_43799 - Tweet: Proud to be Farmer✊
# We demand Repeal!!
#
# #FarmersProtest
# #RepealOnlyWayAhead https://t.co/sPm624vpEN
#
#  - docId: doc_43790 - Tweet: Proud to be Farmer✊
# We demand Repeal!!
#
# #FarmersProtest
# #RepealOnlyWayAhead https://t.co/hxGNKHfUz4
#
#  - docId: doc_18273 - Tweet: Our demand is to release the detained farmers.
#
# #ReleaseDetainedFarmers
# #FarmersProtest
#
#  - docId: doc_17894 - Tweet: Our demand is to release the detained farmers.
#
# #ReleaseDetainedFarmers
# #HumanRights
# #FarmersProtest https://t.co/26fc89oEBH
#
#  - docId: doc_28839 - Tweet: Furious Telangana!
# All India Kisan Mazdoor Sabha today staged a protest in favor of the farmers of Delhi and demanded the repeal of the three laws and the demand for MSP.
#
# #TelanganaNews  #DigitalKisanMorcha #FarmersProtest #KisanAndolan #RememberSirChhotuRamInModiEra https://t.co/SMgEiZyXbJ
#
#  - docId: doc_30921 - Tweet: Lets not forget the farm protest while demanding justice for #DishaRavi. #FarmersProtest ✊🏽 https://t.co/CJxO0fGbBF
#
#  - docId: doc_43437 - Tweet: "SHINE BRIGHT LIKE A DEMAND"
# #RepealOnlyWayAhead
# #farmersprotest https://t.co/T5jaSaspUZ
#
#  - docId: doc_12672 - Tweet: @sachin_rt @akshaykumar @SrBachchan this is what they are demanding for !
# #FarmersProtest #StandWithFarmers https://t.co/GuTLI6sZjc
#
#  - docId: doc_10913 - Tweet: #MSPLawForAllCrops             #FarmersProtest                          What they are demanding is only basic right...Right to live..... https://t.co/FZvvR160BW
#
#  - docId: doc_46147 - Tweet: That's why farmers are demanding guarantee of MSP..
# #FarmersProtest https://t.co/weWkz2AWAz
#
#  - docId: doc_10879 - Tweet: Farmers Deserve and demand MSP of all their crops!!!
#
# #MSPLawForAllCrops
# #FarmersProtest https://t.co/8HrdhSMelY
#
#  - docId: doc_10418 - Tweet: The farmers’ demands are legit. Let’s support them.
# #FarmersProtest
# #MSPLawForAllCrops https://t.co/T7KxHKLegF
#
#  - docId: doc_12705 - Tweet: Sold on msp #Arjun_Tendulkar.
# Exactly this is the demand of farmers who are protesting at delhi borders #MSP_किसान_का_हक #StandWithFarmers #FarmersProtest
#
#  - docId: doc_47735 - Tweet: 207 Farmers gave their lives to this protest!
# We demand Repeal of black laws!
#
# #FarmersProtest
# #MahapanchayatRevolution https://t.co/QoQrikNEb1
#
#  - docId: doc_7128 - Tweet: #ModiIgnoringFarmersDeaths and their demands thinking they will give up.
#
# But the protest judt keeps getting stronger!
#
# #FarmersProtest https://t.co/H4Uu3UU8kR
#
#  - docId: doc_46063 - Tweet: I agree. That needs to be our demand, paper ballots #BanEVM_SaveFarmers
# #MahapanchayatRevolution #FarmersProtest https://t.co/1zMqn5ex0Y
#
#  - docId: doc_43700 - Tweet: Modi regime must act on demands by #FarmersProtest
# #RepealOnlyWayAhead https://t.co/jVDRmkrVef
#
#  - docId: doc_25247 - Tweet: Our only demand is to get these farm bills repealed.
#
# #FarmersMakelndia
# #FarmersProtest https://t.co/tptStTMhho
#
# --------------------------------------------------------------------------------------------------------------------------------
#
#  QUERY 4: Police action during farmers protest
#
#  - docId: doc_24374 - Tweet: #FarmersProtest is in action ! https://t.co/0LAVT2JYsz
#
#  - docId: doc_13980 - Tweet: Why no action on these? #IStandWithFarmers #FarmersProtest #kisanektazindabad  #democracy
#  #Tractor2Twitter #peacefulprotest  #speakupforfarmers
# #WeUnitedForFarmers #shameonbollywood #WorldSupportsIndianFarmers #SpinelessBollywood  #AskIndiaWhy https://t.co/oGwXv9FFVH
#
#  - docId: doc_32026 - Tweet: When police will take action.
# #FarmersProtest https://t.co/U1jaZBge8t
#
#  - docId: doc_5491 - Tweet: The Govt is now showing fear of law to the agitating farmers.People on protesting at Tikri Border are being warned of legal action.
#
#  However,the SHO should have known the difference between action and action before giving warning
# #FarmersProtest
# #SupportFarmers
# #FarmersMakeIndia https://t.co/L2JGRVM0o5
#
#  - docId: doc_34650 - Tweet: If the actions of ppl abroad were not doing good for India’s image globally, the actions of Indian Govt and Delhi Police isn’t bringing glory either. #IndiaBeingSilenced #FarmersProtest https://t.co/z5TEjwIVJH
#
#  - docId: doc_14464 - Tweet: #FarmersProtest . Why is there no action against people who attacked farmers and Delhi police’s standing and watching . Such a corrupt government and police
#
#  - docId: doc_17561 - Tweet: FARMERS' PROTEST
# Educate Yourself.
# Take Action.
# #farmersprotest
# #nofarmersnofood
# #istandwithfarmers
# #kisanektazindabaad https://t.co/JjjvmzEebV
#
#  - docId: doc_33549 - Tweet: Shocking action from GoI #IndiaBeingSilenced #FarmersProtest #ReleaseDishaRavi #ReleaseDetainedFarmers https://t.co/dIz0CKSaFC
#
#  - docId: doc_33540 - Tweet: Shocking action from GoI #IndiaBeingSilenced #FarmersProtest #ReleaseDishaRavi #ReleaseDetainedFarmers https://t.co/894ROynnwK
#
#  - docId: doc_32143 - Tweet: No action against this toolkit? @DelhiPolice
#
# #IndiaBeingSilenced #FreeRanjitSingh #FarmersProtest https://t.co/azY8JGn0nB
#
#  - docId: doc_31632 - Tweet: These are not the actions of a democratic regime. #FarmersProtest.  https://t.co/UZ5g9KDhSS
#
#  - docId: doc_18542 - Tweet: Trust on actions not words. #FarmersProtest #ModiIsThreatForDEMOCRACY https://t.co/ZUqBsE5nND
#
#  - docId: doc_32162 - Tweet: WHY ARE INDIAN THE GOVERNMENT AND POLICE NOT TAKING ACTION AGAINST THESE INTERNET WARRIORS AND ARRESTING THEM ?  #IndiaBeingSilenced #HumanRightsViolations #DishaRavi #FarmersProtest https://t.co/KNWVUdgICC
#
#  - docId: doc_41805 - Tweet: @pmpoc FARMERS' PROTEST
# Educate Yourself.
# Take Action.
# #farmersprotest
# #nofarmersnofood
# #istandwithfarmers
# #kisanektazindabaad
# https://t.co/8el7w32WWs
#
#  - docId: doc_11674 - Tweet: This is the follow up of the  farmer protest in Pakistan Punjab. The leader of farmers filed a murder case for the death of a farmer during the protest by the police and the police rather than rectify the action, arrests him.
# #FarmersProtest #Punjabi
# https://t.co/MCohMY3mS5
#
#  - docId: doc_18802 - Tweet: The #GodiMedia which is CRYING 24/7 #ToolKit #Khalistan #SFJ must watch the first Police action on Farmers in #Pipli on Sep2020 protesting against FarmBills2020! Was Greta/Disha/Dhaliwal behind it?🥳🔥🚜🌾
# https://t.co/ROjOLbJ5XL
# #FarmersProtest #FarmersMakeIndia #FarmersProtests
#
#  - docId: doc_8324 - Tweet: #FarmersProtest
# #FarmersProstests
# #TheWorldIsWatching
# @meenaharris
#
# largest protest of the Whole World in Action ✊🚜🚜🚜 https://t.co/VRL6mNwtIX
#
#  - docId: doc_41801 - Tweet: @TheSyst00873084 @pmpoc FARMERS' PROTEST
# Educate Yourself.
# Take Action.
# #farmersprotest
# #nofarmersnofood
# #istandwithfarmers
# #kisanektazindabaad
# https://t.co/8el7w32WWs
#
#  - docId: doc_33548 - Tweet: @ArvindKejriwal Shocking action from GoI #IndiaBeingSilenced #FarmersProtest #ReleaseDishaRavi #ReleaseDetainedFarmers
#
#  - docId: doc_33539 - Tweet: @amaanbali Shocking action from GoI #IndiaBeingSilenced #FarmersProtest #ReleaseDishaRavi #ReleaseDetainedFarmers
#
#  - docId: doc_33454 - Tweet: Fear is driving the actions of GoI
# #IndiaBeingSilenced #FarmersProtest #ReleaseDishaRavi #ReleaseDetainedFarmers https://t.co/GZuaJ2jVa0
#
#  - docId: doc_32593 - Tweet: Ultimate #Toolkits
# from where all #toolkits of political action are inspired
#
# #FreeDishaRavi
# #FarmersStandingFirm
# #FarmersProtest
# #Farmers https://t.co/uqBZhGkL7T
#
#  - docId: doc_18568 - Tweet: ਗਲੀ ਅਸੀ ਚੰਗੀਆ ਆਚਾਰੀ ਬੁਰੀਆਹ ॥                     We are good at talking, but our actions are bad.                                                              #ThursdayThoughts                                       #FarmersProtest
#
#  - docId: doc_11393 - Tweet: Judiciary has become a joke in India. Why should
# #DishaRavi get bail? Why did other two are still free? When farmer leaders were summoned by Delhi Police, why there is no action against them for not showing up in police station? #FarmersProtest #FarmersProtests #Toolkit
#
#  - docId: doc_44605 - Tweet: Protest actions and propaganda are two slightly different things #FarmersProtest #NoFarmersNoFood
#
#  - docId: doc_22518 - Tweet: Tks, yet to happen. The actions taken by 'Govt of India' against the farmers' protest is absolutely dreading making India a Police State. #undemocraticactions #FarmersProtest https://t.co/Kq73odMGlb
#
#  - docId: doc_40791 - Tweet: Choose wisely before taking any action or participation
# Between #KisanAndolan or #IndiaAgainstPropoganda .
#
# #FarmersProtest https://t.co/mSI8KTJhK3
#
#  - docId: doc_37762 - Tweet: It's easy to feel helpless-like you can't fight the tide.
# But remember: small actions can have a huge impact,one person like u can inspire others to action
# #FarmersProtest
#
#  12:20:09
#
#  - docId: doc_33099 - Tweet: It's easy to feel helpless-like you can't fight the tide.
# But remember: small actions can have a huge impact,one person like u can inspire others to action
# #FarmersProtest #IndiaBeingSilenced
#
#  10:10:11
#
#  - docId: doc_31109 - Tweet: It's easy to feel helpless-like you can't fight the tide.
# But remember: small actions can have a huge impact,one person like u can inspire others to action
# #FarmersProtest #IndiaBeingSilenced
#
#  00:10:08
#
# --------------------------------------------------------------------------------------------------------------------------------
#
#  QUERY 5: Schedules and locations of demonstrations and protests
#
#  - docId: doc_43892 - Tweet: Upcoming #Mahapanchayat schedule
# #MahapanchayatRevolution
# #FarmersProtest https://t.co/uxT8z5Z85M
#
#  - docId: doc_46453 - Tweet: Schedule of Kisan Mahapanchayats announced
# #KisanMahapanchayat #FarmersProtest #schedule #ProtestbyFarmers
#
# https://t.co/nw0zZ2QN8c
#
#  - docId: doc_45516 - Tweet: Schedule of Upcoming MahaPanchayats
#
# @Kisanektamorcha
# #FarmersProtest
# #MahapanchayatRevolution https://t.co/hqRfb8HTM8
#
#  - docId: doc_44233 - Tweet: How many tweets does it takes for a government/police to action?
# Can't locate an aged person?
# LOCATE HIM!!!
# #FarmersProtest
# #FindJorawarSingh
# @PTC_Network @PunjabPoliceInd
# @ndtv @ArvindKejriwal
# @RaviSinghKA @ravishndtv
# @BBCHindi @ANI @AamAadmiParty @diljitdosanjh @DelhiPolice https://t.co/Vyxx3HKrpE
#
#  - docId: doc_45111 - Tweet: Please spread this around to help locate this elder who is missing.
#
# #FarmersProtest https://t.co/9pz6ujvta8
#
#  - docId: doc_45564 - Tweet: Protest demonstration was organised by #CITU in front of the deputy CM of Haryana's house located Sirsa.Demanding the repeal of the black farm law's , anti labour law's and implement the trade unions wise demands.
#
# #FarmersProtest https://t.co/qKs9FMVFAD
#
#  - docId: doc_9157 - Tweet: Farmers block trains in northern India, and a dozen other locations, to protest Modi's repressive laws.
#
# #FarmersProtest https://t.co/xR16j5r0lI
#
#  - docId: doc_19010 - Tweet: Farmers block trains in northern India, and a dozen other locations, to protest Modi's repressive laws.
#
# #FarmersProtest https://t.co/GvuALgbQJ3
#
#  - docId: doc_2192 - Tweet: A civilized country faces demonstrations this way!
# #FarmersProtest https://t.co/Kqwr7rn6kf
#
#  - docId: doc_17302 - Tweet: Watch live demonstrations in India and Myanmar
#
# @ https://t.co/1b2CAtNxqL
#
# #Yangon #Myanmar #WhatisHappeninginMyanmar #Feb19Coup #Rangoon #FarmersProtest #RejectMyanmarMilitaryCoup #CrimesAgainstHumanity #HearTheVoiceOfMyanmar #ReleaseDetainedFarmers
#
#  - docId: doc_16783 - Tweet: Watch live demonstrations in India and Myanmar
#
# @ https://t.co/ON93GsDI5j
#
# #Yangon #Myanmar #WhatisHappeninginMyanmar #Feb19Coup #Rangoon #FarmersProtest #RejectMyanmarMilitaryCoup #CrimesAgainstHumanity #HearTheVoiceOfMyanmar #ReleaseDetainedFarmers #protests
#
#  - docId: doc_3228 - Tweet: #DishaRavi has been brought to cyber cell office and activist Shantanu Muluk is also scheduled to join the probe
#
# #FarmersProtest
#
#  - docId: doc_26556 - Tweet: Kisaan Maha panchayat schedule in UP at various places . Feb 25 is at our place.
#
# #FarmersProtest
#
# #FarmersMakeIndia https://t.co/V3IwBqDe1E
#
#  - docId: doc_41207 - Tweet: #Ottawa come show your support for the #FarmersProtest  and #IndianFarmersHumanRights. Morcha at three locations today: #barrhaven, #kanata, and as per usual in front of the @HCI_Ottawa
#
# #kisanektamorchaottawa https://t.co/Rn7Slw8VbY
#
#  - docId: doc_19312 - Tweet: I want to #askIndiawhy the people who attacked our Grandmothers at Singhu on Jan 28th have not been arrested yet.
# We have their names and locations.
# #FarmersProtest  https://t.co/NnS2dOfeSN
#
#  - docId: doc_43347 - Tweet: Helpdesk : 9779778179
# Location : #DanishTattoozHouse sco 6 ground floor sector 10 #panchkula opp Bus stand. ( #chandigarh )
# #tattooist #tattooing #ink  #tattooartists #indiantattooartist  #Tattooinchandigarh #tattoocultr #tattoobydanish #FarmersProtest https://t.co/T524f84irm
#
#  - docId: doc_42936 - Tweet: We are looking dealers for various locations. To apply the AGRO MALL franchise business, you have to fill a online form through our website.
# #organicagriculture #agriculture_technique #agriculture #agricultureequipment #farmersmarket #farmers #farmersprotest #farmerslife #bjp
#
#  - docId: doc_38629 - Tweet: #FarmersProtest #KisanAndolan
# #SinghuBorder #RepealFarmersLaws #Yangon #Myanmar #WhatsHappeningInMyanmar  #HearTheVoiceOfMyammar
# #DigitalKisan #DigitalKisanMorcha #KisanEktaMorcha
# Watch farmer's protests in Delhi and live demonstrations around Myanmar at https://t.co/1b2CAtNxqL
#
#  - docId: doc_38189 - Tweet: #FarmersProtest #KisanAndolan
# #SinghuBorder #RepealFarmersLaws #Yangon #Myanmar #WhatsHappeningInMyanmar  #HearTheVoiceOfMyammar
# #KisanEktaZindabad  #KisanEktaMorcha #live #protest
# Watch farmer's protests in Delhi and live demonstrations around Myanmar at https://t.co/1b2CAtNxqL
#
#  - docId: doc_20809 - Tweet: Rajasthan: Half a dozen trains scheduled to pass by the Jaipur railway station during the 4-hour long nationwide #RailRoko protest
#
# NDTV's Harsha Kumari Singh reports | #FarmersProtest https://t.co/B6gTdxQ1BG
#
#  - docId: doc_20722 - Tweet: Rajasthan: Half a dozen trains scheduled to pass by the Jaipur railway station during the 4-hour long nationwide #RailRoko protest
#
# NDTV's Harsha Kumari Singh reports | #FarmersProtest
# https://t.co/yJyeO3OI31
#
#  - docId: doc_20438 - Tweet: Farmers call for 4-hour nationwide 'rail roko' demonstration; stage protests at stations.
#
# #NewsAlert #FarmersProtest https://t.co/YVHaIeVR0q
#
#  - docId: doc_1592 - Tweet: Protesting Indian farmers announce a large demonstration near Delhi on February 27
#
# #India #Barnala #FarmerProtest #FarmersProtest #Punjab #Haryana #NewDelhi #Delhi https://t.co/kszeerLelf
#
#  - docId: doc_23067 - Tweet: @nstomar @narendramodi how many more indian citizens you want to see died?
# Are you prime minister just think of your designation if you get time in your tight schedule.
# @rashtrapatibhvn ??
# #FarmersProtest #FarmersProtests #Farmers #FarmersProstests https://t.co/YY1ikqv7Rv
#
#  - docId: doc_48234 - Tweet: #MahapanchayatRevolution Maha “great” mass protests all over India and more scheduled #FarmersProtest - biggest protest in the world @GWR @GerrySimpsonHRW  @JoeBiden @gettleman @cnni @AdamBandt @AlboMP @lenoretaylor @drruthmitchell @antonioguterres @AJIunit @TeamJuJu @UNGeneva https://t.co/fyrhjys7nY
#
#  - docId: doc_47409 - Tweet: Farmer leaders have geared up to intensify the #FarmersProtest. Mahapanchayats will be held across the country to spread awareness and inspire people to join in.
#
# The schedule of a few Mahapanchayats attached.
# #MahapanchayatRevolution https://t.co/BozaQ5b5ox
#
#  - docId: doc_47369 - Tweet: Farmer leaders have geared up to intensify the #FarmersProtest. Mahapanchayats will be held across the country to spread awareness and inspire people to join in.
#
# The schedule of a few Mahapanchayats attached.
# #MahapanchayatRevolution https://t.co/vIpJ4SZpEL
#
#  - docId: doc_46560 - Tweet: Farmer leaders have geared up to intensify the #FarmersProtest. Mahapanchayats will be held across the country to spread awareness and inspire people to join in.
#
# The schedule of a few Mahapanchayats attached.
# #MahapanchayatRevolution https://t.co/8smq72M4f8
#
#  - docId: doc_45381 - Tweet: Schedule of upcoming mahapanchyats. #MahapanchayatRevolution #FarmersProtest #Revoke3FarmActs @hrw @cnn @UNHumanRights @BBCWorld @AlJazeera_World @JoeBiden @TimUppal @amnesty @TanDhesi @JustinTrudeau @bbcpunjabi @BorisJohnson @jacindaardern @Australia @nypost @BBCHindi https://t.co/MUP4dAAkml
#
#  - docId: doc_27672 - Tweet: JUSTICE FOR FARMERS
#
# Release detained protestors
# Locate missing farmers
# Repeal farm laws
# NO MORE FARMER DEATHS
#
# #FarmersProtest #FreeDishaRavi https://t.co/8CFiDKdIEJ

# %%
# aabans de fer l'execució mirar si quadren els resultats
# si no ho son posar un 0 a label

# query 1
non_relevant_doc_ids_q1 = [
    "doc_3234", "doc_27784", "doc_38114", "doc_38045", "doc_32344",
    "doc_24570", "doc_24061", "doc_17249", "doc_37157", "doc_2453",
    "doc_19626", "doc_45649", "doc_43568", "doc_10847", "doc_10556"
]
evaluation_datasets[0].loc[evaluation_datasets[0]['docId'].isin(non_relevant_doc_ids_q1), 'label'] = 0

# query 2
non_relevant_doc_ids_q2 = [
    "doc_12950", "doc_38762", "doc_21630", "doc_6713", "doc_28710",
    "doc_42972", "doc_28358", "doc_27294", "doc_25064", "doc_17785",
    "doc_42502", "doc_6920", "doc_6031", "doc_48125", "doc_44813",
    "doc_41492", "doc_29827", "doc_28889", "doc_1896", "doc_40083"
]
evaluation_datasets[1].loc[evaluation_datasets[1]['docId'].isin(non_relevant_doc_ids_q2), 'label'] = 0

# query 3
non_relevant_doc_ids_q3 = [
    "doc_15908", "doc_10445", "doc_18128", "doc_887", 
    "doc_43810", "doc_43799", "doc_43790", "doc_12672", 
    "doc_7128", "doc_46063"
]
evaluation_datasets[2].loc[evaluation_datasets[2]['docId'].isin(non_relevant_doc_ids_q3), 'label'] = 0


# query 4
non_relevant_doc_ids_q4 = [
    "doc_24374", "doc_13980", "doc_32026", "doc_5491", "doc_34650",
    "doc_14464", "doc_17561", "doc_33549", "doc_33540", "doc_32143",
    "doc_31632", "doc_18542", "doc_32162", "doc_41805", "doc_11674",
    "doc_18802", "doc_8324", "doc_41801", "doc_33548", "doc_33539",
    "doc_33454", "doc_32593", "doc_18568", "doc_11393", "doc_44605",
    "doc_22518", "doc_40791", "doc_37762", "doc_33099", "doc_31109"
]
evaluation_datasets[3].loc[evaluation_datasets[3]['docId'].isin(non_relevant_doc_ids_q4), 'label'] = 0

# query 5 
non_relevant_doc_ids_q5 = [
    "doc_44233", "doc_45111", "doc_45564", "doc_9157",
    "doc_19010", "doc_2192", "doc_17302", "doc_16783",
    "doc_3228", "doc_38629", "doc_38189", "doc_19312", 
    "doc_43347", "doc_42936", "doc_23067", "doc_23067",
    "doc_27672"
]
evaluation_datasets[4].loc[evaluation_datasets[4]['docId'].isin(non_relevant_doc_ids_q5), 'label'] = 0

# %%
# print results for our queries
k = 10
print_evaluation_metrics(queries, evaluation_datasets, k)
# Out:
# ----------------------------------------------------------------------------------------------------------
#
# Query: 'Indian government response to farmers'
#
# => Precision@10: 0.5
#
# => Recall@10: 1.0
#
# => Average Precision@10: 0.4035
#
# => F1-Score@10: 0.6667
#
# => MAP with k=10: 0.8762
#
# => Mean Reciprocal Rank with k=10: 0.2
#
# => Normalized Discounted Cumulative Gain with k=10: 0.3726
#
# ----------------------------------------------------------------------------------------------------------
#
# Query: 'International support for farmers'
#
# => Precision@10: 0.3
#
# => Recall@10: 1.0
#
# => Average Precision@10: 0.8667
#
# => F1-Score@10: 0.4615
#
# => MAP with k=10: 0.6429
#
# => Mean Reciprocal Rank with k=10: 1.0
#
# => Normalized Discounted Cumulative Gain with k=10: 0.4441
#
# ----------------------------------------------------------------------------------------------------------
#
# Query: 'Demands of farmers' protests'
#
# => Precision@10: 0.7
#
# => Recall@10: 1.0
#
# => Average Precision@10: 0.7546
#
# => F1-Score@10: 0.8235
#
# => MAP with k=10: 0.3917
#
# => Mean Reciprocal Rank with k=10: 0.5
#
# => Normalized Discounted Cumulative Gain with k=10: 0.65
#
# ----------------------------------------------------------------------------------------------------------
#
# Query: 'Police action during farmers protest'
#
# => Precision@10: 0.0
#
# => Recall@10: 0.0
#
# => Average Precision@10: 0
#
# => F1-Score@10: 0
#
# => MAP with k=10: 0.0
#
# => Mean Reciprocal Rank with k=10: 0
#
# => Normalized Discounted Cumulative Gain with k=10: 0
#
# ----------------------------------------------------------------------------------------------------------
#
# Query: 'Schedules and locations of demonstrations and protests'
#
# => Precision@10: 0.3
#
# => Recall@10: 1.0
#
# => Average Precision@10: 1.0
#
# => F1-Score@10: 0.4615
#
# => MAP with k=10: 0.7254
#
# => Mean Reciprocal Rank with k=10: 1.0
#
# => Normalized Discounted Cumulative Gain with k=10: 0.469

# %% [markdown]
# **Task 2:**
#
# **Choose one vector representation, TF-IDF or word2vec, and represent the tweets in a two-dimensional scatter plot through the T-SNE (T-distributed Stochastic Neighbor Embedding) algorithm. To do so, you may need first to represent the word as a vector, and then the tweet, i.e., resulted as the average value over the words involved. Any other option rather than T-SNE may be used, but needs to be justified.**

# %%
# apply word2vec model
model = Word2Vec(sentences=processed_tweets_df['Tweet'], vector_size=100, window=5, min_count=1, workers=4)

# %%
# extract words and vectors from the model
words, word_vectors = zip(*[(word, model.wv[word]) for word in model.wv.index_to_key])
# Convert word vectors to a NumPy array for t-SNE processing
word_vectors = np.array(word_vectors)

# %%
# Initialize and fit the t-SNE model
tsne_model = TSNE(perplexity=40, n_components=2, init='pca', max_iter=3500, random_state=23)
tsne_results = tsne_model.fit_transform(word_vectors)

# %%
# Plot the results
plt.figure(figsize=(30, 30))
x, y = tsne_results[:, 0], tsne_results[:, 1]

for i, word in enumerate(words):
    plt.scatter(x[i], y[i])
    plt.annotate(word,
                 xy=(x[i], y[i]),
                 xytext=(4, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

plot_filename = 'tsne_plot.png'  
plt.savefig(plot_filename)  # save the figure to a file
plt.close()  # close the plot to avoid displaying it
